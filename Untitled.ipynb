# %%
install.packages("roxygen2")
library(roxygen2)
# Out:
# also installing the dependency ‘rlang’
#
#
# Warning message in install.packages("roxygen2"):
# “installation of one or more packages failed,
#   probably ‘rlang’, ‘roxygen2’”
# Warning message:
# “package ‘roxygen2’ was built under R version 4.1.3”

# %%
roxygen2::roxygenise()
# Out:
# First time using roxygen2. Upgrading automatically...
# Setting `RoxygenNote` to "7.2.1"
# ℹ Loading scDecouple
# Warning message:
# “package ‘Seurat’ was built under R version 4.1.2”
# Warning message:
# “Skipping NAMESPACE
# ✖ It already exists and was not generated by roxygen2.”
# Warning message:
# “Skipping NAMESPACE
# ✖ It already exists and was not generated by roxygen2.”
# Writing data_preprocessing.Rd
# Writing downstream_analysis.Rd
# Writing get_beta_EM_sep_method.Rd
# Writing pc_selection.Rd
# Writing run_scDecouple.Rd
# Writing scDecouple.Rd
